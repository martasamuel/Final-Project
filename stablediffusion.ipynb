# %%
# !pip install torch torchvision torchaudio
# !pip install transformers
# !pip install diffusers
# !pip install accelerate
# !pip install numpy matplotlib
# Out:
# Collecting torch
#   Downloading torch-2.4.1-cp38-none-macosx_11_0_arm64.whl.metadata (26 kB)
# Collecting torchvision
#   Downloading torchvision-0.19.1-cp38-cp38-macosx_11_0_arm64.whl.metadata (6.0 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.4.1-cp38-cp38-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from torch) (4.12.2)
# Collecting sympy (from torch)
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting numpy (from torchvision)
#   Downloading numpy-1.24.4-cp38-cp38-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-10.4.0-cp38-cp38-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading MarkupSafe-2.1.5-cp38-cp38-macosx_10_9_universal2.whl.metadata (3.0 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading torch-2.4.1-cp38-none-macosx_11_0_arm64.whl (62.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 MB 52.0 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.19.1-cp38-cp38-macosx_11_0_arm64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 50.6 MB/s eta 0:00:00
# Downloading torchaudio-2.4.1-cp38-cp38-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 44.5 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp38-cp38-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 57.7 MB/s eta 0:00:00
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 57.5 MB/s eta 0:00:00
# Downloading numpy-1.24.4-cp38-cp38-macosx_11_0_arm64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 72.8 MB/s eta 0:00:00
# Using cached sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Downloading MarkupSafe-2.1.5-cp38-cp38-macosx_10_9_universal2.whl (18 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, pillow, numpy, networkx, MarkupSafe, fsspec, filelock, jinja2, torch, torchvision, torchaudio
# Successfully installed MarkupSafe-2.1.5 filelock-3.16.1 fsspec-2025.3.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.1 numpy-1.24.4 pillow-10.4.0 sympy-1.13.3 torch-2.4.1 torchaudio-2.4.1 torchvision-0.19.1
# Collecting transformers
#   Downloading transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from transformers) (3.16.1)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers)
#   Downloading huggingface_hub-0.30.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from transformers) (24.2)
# Collecting pyyaml>=5.1 (from transformers)
#   Downloading pyyaml-6.0.2.tar.gz (130 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2024.11.6-cp38-cp38-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting requests (from transformers)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tokenizers<0.21,>=0.20 (from transformers)
#   Downloading tokenizers-0.20.3-cp38-cp38-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Using cached safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
#   Downloading charset_normalizer-3.4.1-cp38-cp38-macosx_10_9_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests->transformers)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->transformers)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Downloading transformers-4.46.3-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 6.8 MB/s eta 0:00:00 0:00:01
# Downloading huggingface_hub-0.30.2-py3-none-any.whl (481 kB)
# Downloading regex-2024.11.6-cp38-cp38-macosx_11_0_arm64.whl (284 kB)
# Using cached safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
# Downloading tokenizers-0.20.3-cp38-cp38-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 7.0 MB/s eta 0:00:00a 0:00:01
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp38-cp38-macosx_10_9_universal2.whl (195 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (pyproject.toml) ... done
#   Created wheel for pyyaml: filename=pyyaml-6.0.2-cp38-cp38-macosx_11_0_arm64.whl size=45364 sha256=42fed6c9fadf8668d9f499a0535c58dafa119e538767948ac5069078ce28673c
#   Stored in directory: /Users/martakarnaschodkiewicz/Library/Caches/pip/wheels/ab/34/2b/5ad179dc5914ad34b84b05b4fd1c3f7a39fee3e771ddf534a4
# Successfully built pyyaml
# Installing collected packages: urllib3, tqdm, safetensors, regex, pyyaml, idna, charset-normalizer, certifi, requests, huggingface-hub, tokenizers, transformers
# Successfully installed certifi-2025.1.31 charset-normalizer-3.4.1 huggingface-hub-0.30.2 idna-3.10 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 safetensors-0.5.3 tokenizers-0.20.3 tqdm-4.67.1 transformers-4.46.3 urllib3-2.2.3
# Collecting diffusers
#   Downloading diffusers-0.33.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: importlib-metadata in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from diffusers) (8.5.0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from diffusers) (3.16.1)
# Requirement already satisfied: huggingface-hub>=0.27.0 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from diffusers) (0.30.2)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from diffusers) (1.24.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from diffusers) (0.5.3)
# Requirement already satisfied: Pillow in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from diffusers) (10.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from huggingface-hub>=0.27.0->diffusers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from huggingface-hub>=0.27.0->diffusers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from huggingface-hub>=0.27.0->diffusers) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from huggingface-hub>=0.27.0->diffusers) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from huggingface-hub>=0.27.0->diffusers) (4.12.2)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from importlib-metadata->diffusers) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from requests->diffusers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from requests->diffusers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from requests->diffusers) (2025.1.31)
# Downloading diffusers-0.33.1-py3-none-any.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 27.3 MB/s eta 0:00:00
# Installing collected packages: diffusers
# Successfully installed diffusers-0.33.1
# Collecting accelerate
#   Downloading accelerate-1.0.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from accelerate) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from accelerate) (5.8.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from accelerate) (2.4.1)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from accelerate) (0.30.2)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: requests in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from torch>=1.10.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from torch>=1.10.0->accelerate) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.1.31)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading accelerate-1.0.1-py3-none-any.whl (330 kB)
# Installing collected packages: accelerate
# Successfully installed accelerate-1.0.1
# Requirement already satisfied: numpy in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (1.24.4)
# Collecting matplotlib
#   Downloading matplotlib-3.7.5-cp38-cp38-macosx_11_0_arm64.whl.metadata (5.7 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.1.1-cp38-cp38-macosx_11_0_arm64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.57.0-cp38-cp38-macosx_10_9_universal2.whl.metadata (102 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp38-cp38-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from matplotlib) (10.4.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from matplotlib) (2.9.0)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: zipp>=3.1.0 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/stablediff/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.7.5-cp38-cp38-macosx_11_0_arm64.whl (7.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 47.9 MB/s eta 0:00:00
# Downloading contourpy-1.1.1-cp38-cp38-macosx_11_0_arm64.whl (232 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp38-cp38-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 55.5 MB/s eta 0:00:00
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Downloading kiwisolver-1.4.7-cp38-cp38-macosx_11_0_arm64.whl (64 kB)
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Installing collected packages: pyparsing, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.57.0 importlib-resources-6.4.5 kiwisolver-1.4.7 matplotlib-3.7.5 pyparsing-3.1.4

# %%
from diffusers import StableDiffusionPipeline
import torch

# Load the correct model (no need for "-original")
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4")

# Use CPU or GPU depending on availability
device = "cuda" if torch.cuda.is_available() else "cpu"
pipe = pipe.to(device)
# Out:
# Fetching 16 files:   6%|▋         | 1/16 [00:00<00:05,  2.98it/s]Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Fetching 16 files:  19%|█▉        | 3/16 [00:00<00:02,  6.08it/s]Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Fetching 16 files: 100%|██████████| 16/16 [01:18<00:00,  4.89s/it]
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00, 17.13it/s]

# %%
prompt = "A pink flower in the style of Van Gogh"
image = pipe(prompt).images[0]
image.show()
# Out:
# 100%|██████████| 50/50 [05:34<00:00,  6.69s/it]

# %%
image.save("generated_image.png")
